# %% [markdown]
# <a href="https://colab.research.google.com/github/Betty1480/hotel-analysis/blob/main/cognitive_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task: Top Cuisines
#
# Determine the top three most
# common cuisines in the dataset.

# %% [markdown]
# # **Level 1**
#
# # Task **1**

# %% [markdown]
# # Task: Top **Cuisines**

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Dataset  (1).csv')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# Determine the top three most
# common cuisines in the dataset.

# %%
df.Cuisines.value_counts()
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
df.Cuisines.value_counts().head(3)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %% [markdown]
# # Calculate the percentage of restaurants that serve each of the top
# ### cuisines.

# %%
df.Cuisines.value_counts().head(3)/len(df)*100
# Out:
# Cuisines
# North Indian             9.800021
# North Indian, Chinese    5.350225
# Chinese                  3.706418
# Name: count, dtype: float64

# %% [markdown]
# # Task: City **Analysis**
#
# # Identify the city with the highest number of restaurants in the dataset.

# %%
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
df.City.value_counts()
# Out:
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: count, Length: 141, dtype: int64

# %%
df.City.value_counts().head(1)
# Out:
# City
# New Delhi    5473
# Name: count, dtype: int64

# %%
df.groupby('City')['Restaurant Name'].value_counts().sort_values(ascending=False).head(1)
# Out:
# City       Restaurant Name
# New Delhi  Cafe Coffee Day    57
# Name: count, dtype: int64

# %%
df.groupby('City')['Restaurant Name'].apply(lambda x: x.value_counts().idxmax())
# Out:
# City
# Abu Dhabi                                           Denny's
# Agra                                             Jahanpanah
# Ahmedabad                          650 - The Global Kitchen
# Albany                          Austin's BBQ and Oyster Bar
# Allahabad                            Aryan Family's Delight
#                                      ...
# Weirton            Theo Yianni's Authentic Greek Restaurant
# Wellington City                                Maranui Cafe
# Winchester Bay                    Fishpatrick's Crabby Cafe
# Yorkton                                       Arigato Sushi
# ��stanbul                               J'adore Chocolatier
# Name: Restaurant Name, Length: 141, dtype: object

# %% [markdown]
# # Calculate the average rating for restaurants in each city.

# %%
df.groupby('City')['Aggregate rating'].mean()
# Out:
# City
# Abu Dhabi          4.300000
# Agra               3.965000
# Ahmedabad          4.161905
# Albany             3.555000
# Allahabad          3.395000
#                      ...
# Weirton            3.900000
# Wellington City    4.250000
# Winchester Bay     3.200000
# Yorkton            3.300000
# ��stanbul          4.292857
# Name: Aggregate rating, Length: 141, dtype: float64

# %%
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
df.groupby('City')[Restaurant Name]['Aggregate rating'].mean().sort_values(ascending=False)

# %%
df.groupby(['City', 'Restaurant Name'])['Aggregate rating'].mean().sort_values(ascending=False)
# Out:
# City       Restaurant Name
# Dubai      Carnival By Tresind                     4.9
# Guwahati   Barbeque Nation                         4.9
# London     Bao                                     4.9
# Augusta    Rae's Coastal Cafe                      4.9
# Jaipur     Zolocrust - Hotel Clarks Amer           4.9
#                                                   ...
# New Delhi  Faeem Chicken Corner                    0.0
#            Facebook Fast Food                      0.0
#            Fabulous Cake                           0.0
#            The Darjiling Delicious Chinese Food    0.0
# Gurgaon    Delicious Food Corner                   0.0
# Name: Aggregate rating, Length: 7974, dtype: float64

# %% [markdown]
# # Determine the city with the highest average rating.**bold text**

# %%
df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False).head(1)
# Out:
# City
# Inner City    4.9
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# # **Task: Price Range Distribution**
#
# # **Create a histogram or bar chart to visualize the distribution of price ranges among the restaurants.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df['Price range'].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
df.groupby('Price range')['Restaurant Name'].count()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Restaurant Name, dtype: int64

# %%
df

# %% [markdown]
# # **Task: Price Range Distribution**
#
# # Create a histogram or bar chart to visualize the distribution of price ranges
# # among the restaurants. **bold text****bold text**

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='Price range')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Price range', palette='viridis')
plt.title('Price Range Distribution Among Restaurants')
plt.xlabel('Price Range')
plt.ylabel('Number of Restaurants')
plt.show
# Out:
# <ipython-input-10-6471508714ea>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Price range', palette='viridis')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=price_range_counts.index, y=price_range_counts.values, palette='viridis')
plt.title('Price Range Distribution Among Restaurants')
plt.xlabel('Price Range')
plt.ylabel('Number of Restaurants')
plt.show()

# %% [markdown]
# # Calculate the percentage of restaurants
# # in each price range category. **bold text**

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.groupby('Price range')['Restaurant Name'].count()/len(df) * 100
# Out:
# Price range
# 1    46.529159
# 2    32.593446
# 3    14.741912
# 4     6.135483
# Name: Restaurant Name, dtype: float64

# %% [markdown]
# # Task 4
# # : Online Delivery
#
# # Determine the percentage of restaurants that offer online delivery.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.groupby('Has Online delivery')['Restaurant Name'].count()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: Restaurant Name, dtype: int64

# %%
df.groupby('Has Online delivery')['Restaurant Name'].count()/len(df) * 100
# Out:
# Has Online delivery
# No     74.337766
# Yes    25.662234
# Name: Restaurant Name, dtype: float64

# %% [markdown]
# # Compare the average ratings of restaurants with and without online delivery.

# %%
df.groupby('Has Online delivery')['Aggregate rating'].mean()
# Out:
# Has Online delivery
# No     2.465296
# Yes    3.248837
# Name: Aggregate rating, dtype: float64

# %%
df.groupby('Has Online delivery')['Aggregate rating'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Has Online delivery'>

# %% [markdown]
# # **LEVEL 2**
#  # Task 1 : **Restaurant** Ratings
#
# # Analyze the **distribution** of aggregate ratings and determine the most common rating range.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.groupby('Aggregate rating')['Restaurant Name'].count()
# Out:
# Aggregate rating
# 0.0    2148
# 1.8       1
# 1.9       2
# 2.0       7
# 2.1      15
# 2.2      27
# 2.3      47
# 2.4      87
# 2.5     110
# 2.6     191
# 2.7     250
# 2.8     315
# 2.9     381
# 3.0     468
# 3.1     519
# 3.2     522
# 3.3     483
# 3.4     498
# 3.5     480
# 3.6     458
# 3.7     427
# 3.8     400
# 3.9     335
# 4.0     266
# 4.1     274
# 4.2     221
# 4.3     174
# 4.4     144
# 4.5      95
# 4.6      78
# 4.7      42
# 4.8      25
# 4.9      61
# Name: Restaurant Name, dtype: int64

# %%
df.groupby('Aggregate rating')['Restaurant Name'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Aggregate rating'>

# %% [markdown]
# # Calculate the average number of votes
# # received by restaurants.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.groupby('Aggregate rating')['Votes'].mean()
# Out:
# Aggregate rating
# 0.0       0.870112
# 1.8     322.000000
# 1.9     106.000000
# 2.0     129.714286
# 2.1      76.400000
# 2.2      94.962963
# 2.3      69.808511
# 2.4      97.011494
# 2.5      79.672727
# 2.6      53.921466
# 2.7      52.376000
# 2.8      31.755556
# 2.9      17.608924
# 3.0      20.153846
# 3.1      32.163776
# 3.2      45.103448
# 3.3      72.207039
# 3.4      94.162651
# 3.5     142.429167
# 3.6     165.120087
# 3.7     261.067916
# 3.8     266.315000
# 3.9     357.149254
# 4.0     405.560150
# 4.1     466.828467
# 4.2     518.303167
# 4.3     673.367816
# 4.4     653.291667
# 4.5     716.157895
# 4.6     731.102564
# 4.7    1089.166667
# 4.8    1197.880000
# 4.9     911.967213
# Name: Votes, dtype: float64

# %% [markdown]
# # Task2 : Cuisine Combination
#
# # Identify the most common combinations of
# # cuisines in the dataset.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.Cuisines.value_counts()
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %% [markdown]
# # Determine if certain cuisine combinations tend to have higher ratings.

# %%
df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)
# Out:
# Cuisines
# Italian, Deli                     4.9
# Hawaiian, Seafood                 4.9
# American, Sandwich, Tea           4.9
# Continental, Indian               4.9
# European, Asian, Indian           4.9
#                                  ...
# Fast Food, Desserts, Beverages    0.0
# Fast Food, Chinese, Burger        0.0
# Cafe, French                      0.0
# Seafood, Mughlai, North Indian    0.0
# Fast Food, Mughlai, Armenian      0.0
# Name: Aggregate rating, Length: 1825, dtype: float64

# %% [markdown]
# # Task 3
# # : **Geographic** Analysis
#
# # Plot the locations of restaurants on a
# # map using longitude and latitude
# # coordinates.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Longitude',y='Latitude',data=df)
plt.show()

# %% [markdown]
# # Identify any patterns or clusters of restaurants in specific areas.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.groupby('Locality')['Restaurant Name'].count().sort_values(ascending=False)
# Out:
# Locality
# Connaught Place        122
# Rajouri Garden          99
# Shahdara                87
# Defence Colony          86
# Malviya Nagar           85
#                       ...
# Plaza Mall, MG Road      1
# Grovetown                1
# Podanur                  1
# Pondok Aren              1
# ��mitk�_y                1
# Name: Restaurant Name, Length: 1208, dtype: int64

# %% [markdown]
# # Level 2
#
# # **Task** 4
# # Task: **Restaurant** Chains
#
# # Identify if there are any restaurant chains present in the dataset.

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.groupby('Has Table booking')['Restaurant Name'].count()
# Out:
# Has Table booking
# No     8393
# Yes    1158
# Name: Restaurant Name, dtype: int64

# %%
df.groupby('Has Table booking')['Restaurant Name'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Has Table booking'>

# %%
df

# %% [markdown]
# # **Analyze the ratings and popularity of different restaurant chains.**

# %%
df.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
#
# [1 rows x 21 columns]

# %%
df.groupby('Has Table booking')['Aggregate rating'].mean()
# Out:
# Has Table booking
# No     2.559359
# Yes    3.441969
# Name: Aggregate rating, dtype: float64

# %%
df.groupby('Has Table booking')['Aggregate rating'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Has Table booking'>

# %% [markdown]
# # **Level 3**
#
# # Task 1;Task:**bold text** Restaurant Reviews

# %% [markdown]
# # Analyze the text reviews to identify the most **common** positive and negative keywords. **bold text**

# %% [markdown]
# # **Calculate the average length of reviews and explore if there is a relationship between review length and rating.**

# %% [markdown]
# # **Level** 3
#
# # Task 2Task: Votes Analysis

# %% [markdown]
# # **Identify the restaurants with the highest and lowest number of votes.**

# %% [markdown]
# # Analyze if there is a correlation between the
# # number of votes and the rating of a
# # restaurant.**bold text**

# %% [markdown]
# # **Level 3**
#
# # Task **3**
#
# # Task: Price Range vs. Online Delivery and
# # Table **Booking**

# %% [markdown]
# # **Analyze if there is a relationship between the price range and the availability of online delivery and table booking.**

# %% [markdown]
# # Determine if higher-priced restaurants are **more** likely to offer these services.
